# %% [markdown]
# # <a href="http://ipython.org/notebook.html">Ipython notebook : </a> cours <a href="#Plan">INPROS</a> <a href="http://inpros.univ-lyon1.fr"><img style=" float:right; display:inline; width:120px;" src="Figures/logo_trans.png" alt="LyonHPC" /></a>
# <h5>
# **Auteur: ** <a href="http://ufrmeca.univ-lyon1.fr/~buffat">Marc BUFFAT</a>, Pr dpt de Mécanique, UCB Lyon 1
#
# **Contributeurs: ** Violaine Louvet, Michel Kern, Loic Gouarin, Laurence Viry
# </h5>
# <h6>
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/2.0/fr/"><img alt="Licence Creative Commons" style="border-width:0;float:right;" src="Figures/cc.png" /></a><br />Mise à disposition selon les termes de la <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/2.0/fr/">Licence Creative Commons <br> Attribution - Pas d’Utilisation Commerciale - Partage dans les Mêmes Conditions 2.0 France</a>.
# </h6>

# %%
# %matplotlib inline
# %autosave 300
from IPython.display import HTML,display
css_file = 'style.css'
try:
    display(HTML(open(css_file, "r").read()))
    print "using ",css_file
except :
    print "using default css"
# Out:
# Autosaving every 300 seconds
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 850px;
# }
#
#
# div #notebook { /* centre the content */
# ...

# %% [markdown]
# # <a href="#ici000">Plan du cours</a><a id="ici000"/>

# %% [markdown]
# <div style="width:600px; overflow:auto;">
# <center>
# <img style=" float:center; display:inline; width:180px;" src="Figures/logo_trans.png" alt="LyonHPC" />
# <img style=" float:center; display:inline; width:200px;" src="Figures/python-logo.gif" alt="LyonHPC"/>
# </center>
# </div>
# <img style="width:250px;" src="Figures/cloud_intro.png">

# %% [markdown]
# # <a href="#Plan">Sommaire des leçons</a><a name="Plan" /></a><a href="http://INPROS.univ-lyon1.fr"><img style=" float:right; display:inline; width:120px;" src="files/logo_trans.png" alt="LyonHPC" /></a>
# <h5>
# 1. <a href="COURS_RAPPEL">Rappels de mathématique et de mécanique newtonienne</a>
# 1. <a href="COURS_INTRO"> Leçon 1: Introduction</a>
# 1. <a href="COURS_ORDI"> Leçon 2: Fonctionnement d'un ordinateur</a>
# 1. <a href="COURS_VAR"> Leçon 3: Utilisation des variables</a>
# 1. <a href="COURS_LOOP"> Leçon 4: Structures de contrôle</a>
# 1. <a href="COURS_FONCTION"> Leçon 5: Procédures et fonctions</a>
# 1. <a href="COURS_TABLEAU"> Leçon 6: Les tableaux numpy (vecteurs, matrices)</a>
# 1. Leçon 7: Tracé avec matplotlib et gestion de fichiers
#    -  <a href="COURS_PLOT"> Tracé avec matplotlib</a>
#    -  <a href="COURS_FICHIER">Gestion de fichiers et E/S</a>
# 1. <a href="COURS_PRECISION"> Leçon 8: Précision des calculs, validation des programmes</a>
# 1. <a href="COURS_ALGORITHME"> Leçon 9: Algorithmes numériques de base</a>
# 1. <a href="COURS_EFFICIENCY"> Leçon 10: Efficacité/complexité des algorithmes</a>
# 1. <a href="COURS_DEBUG"> Leçon 11: Recherche d'erreur (debugging)</a>

# %% [markdown]
# # <a href="#sommaire">Compléments de cours</a><a name="complements"></a>
#
# ## Livres sur Python
# - *Apprendre à programmer avec Python* de Gérard Swinnen en téléchargement libre ici [http://inforef.be/swi/python.htm](http://inforef.be/swi/python.htm)
#
# - *How to Think Like a Computer Scientist* par Peter Wentworth, Jeffrey Elkner, Allen B. Downey, et Chris Meyers en téléchargement libre ici (openbook) [How to Think Like a Computer Scientist](http://openbookproject.net/thinkcs/python/english3e/index.html)
#
#
#
# ## Cours sur la programmation
#
# - OpenCourseWare MIT 6.00x: *Introduction to Computer Science and Programming* par Eric Grimson et John Guttag
# [Introduction to computer science and programming](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-00-introduction-to-computer-science-and-programming-fall-2008/)
#
# - Standford CS101: *Introduction to computer science* par Nick Parlante
# [https://class.coursera.org/cs101/lecture](https://class.coursera.org/cs101/lecture)
#
# - George Washington University: *MAE6286 Practical Numerical Methods with Python* par Lorena A. Barbara [http://openedx.seas.gwu.edu/courses](http://openedx.seas.gwu.edu/courses)
#
# ## Références (Python 2.7)
# - [Python 2.7 référence (Python.org)](https://docs.python.org/2.7)
# - [Programmation en Python (Wikibook)](http://fr.wikibooks.org/wiki/Programmation_Python)
# - [Learn Python The Hard Way](http://learnpythonthehardway.org/book/)
# - [Arithmétique en virgule flottante](https://docs.python.org/2/tutorial/floatingpoint.html#tut-fp-issues)
#
# ## Vidéos
# - Le film suivant:[http://www-sop.inria.fr/science-participative/film/](http://www-sop.inria.fr/science-participative/film/)
# a été produit par l’Inria (Institut national de recherche en informatique et automatisme) et retrace l’histoire de l’informatique du 9e siècle à aujourd’hui en 24 minutes.
#
# - Le sketch [Spam](https://www.youtube.com/watch?v=M_eYSuPKP3Y) des [Monty Python](http://fr.wikipedia.org/wiki/Monty_Python) (qui ont beaucoup inspiré la communauté Python), où deux clients tentent de commander un repas à l'aide d'une carte qui contient du jambon en conserve de marque SPAM dans pratiquement tous les plats. Ce sketch a été pris pour référence pour désigner un email non sollicité (spam).

# %% [markdown]
# #Fin du cours
# <div style="width:600px; overflow:auto;">
# <center>
# <img style=" float:center; display:inline; width:180px;" src="files/logo_trans.png" alt="LyonHPC" />
# <img style=" float:center; display:inline; width:200px;" src="files/python-logo.gif" alt="LyonHPC"/>
# </center>
# </div>
# <img style="width:250px;" src="Figures/cloud_intro.png">
